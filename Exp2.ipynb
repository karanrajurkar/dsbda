# %%
import numpy as np
import pandas as pd
data=pd.read_csv("StudentsPerformance.csv")
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
data.isnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0     False           False                        False  False
# 1     False           False                        False  False
# 2     False           False                        False  False
# 3     False           False                        False  False
# 4     False           False                        False  False
# ..      ...             ...                          ...    ...
# 995   False           False                        False  False
# 996   False           False                        False  False
# 997   False           False                        False  False
# 998   False           False                        False  False
# 999   False           False                        False  False
#
#      test preparation course  math score  reading score  writing score
# 0                      False       False          False          False
# ...

# %%
data.notnull()
# Out:
#      gender  race/ethnicity  parental level of education  lunch  \
# 0      True            True                         True   True
# 1      True            True                         True   True
# 2      True            True                         True   True
# 3      True            True                         True   True
# 4      True            True                         True   True
# ..      ...             ...                          ...    ...
# 995    True            True                         True   True
# 996    True            True                         True   True
# 997    True            True                         True   True
# 998    True            True                         True   True
# 999    True            True                         True   True
#
#      test preparation course  math score  reading score  writing score
# 0                       True        True           True           True
# ...

# %%
data.dropna()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data['math score'].fillna(value=0,inplace=True)
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.fillna(0,inplace=True)
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
num = data._get_numeric_data()
num[num<0]=0
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import seaborn as sns
sns.boxplot(data['math score'])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize = (18,10))
ax.scatter(data['writing score'], data['reading score'])
 
# x-axis label
ax.set_xlabel('math score')
 
# y-axis label
ax.set_ylabel('reading score')
plt.show()

# %%
from scipy import stats
import numpy as np
 
z = np.abs(stats.zscore(data['reading score']))
print(z)
# Out:
# 0      0.193999
# 1      1.427476
# 2      1.770109
# 3      0.833899
# 4      0.605158
#          ...
# 995    2.044215
# 996    0.970952
# 997    0.125472
# 998    0.605158
# 999    1.153370
# Name: reading score, Length: 1000, dtype: float64

# %%
threshold = 3
 
# Position of the outlier
print(np.where(z > 3))
# Out:
# (array([ 59, 327, 596, 980], dtype=int64),)

# %%
Q1 = np.percentile(data['reading score'], 25, interpolation = 'midpoint')
Q3 = np.percentile(data['reading score'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
IQR
# Out:
# C:\Users\vasek\AppData\Local\Temp\ipykernel_9064\1384664367.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(data['reading score'], 25, interpolation = 'midpoint')
# C:\Users\vasek\AppData\Local\Temp\ipykernel_9064\1384664367.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(data['reading score'], 75, interpolation = 'midpoint')
# 20.0

# %%
data.fillna(0,inplace=True)
print(data.to_string())
# Out:
#      gender race/ethnicity parental level of education         lunch test preparation course  math score  reading score  writing score
# 0    female        group B           bachelor's degree      standard                    none          72             72             74
# 1    female        group C                some college      standard               completed          69             90             88
# 2    female        group B             master's degree      standard                    none          90             95             93
# 3      male        group A          associate's degree  free/reduced                    none          47             57             44
# 4      male        group C                some college      standard                    none          76             78             75
# 5    female        group B          associate's degree      standard                    none          71             83             78
# ...

# %%
Q1 = np.percentile(data['math score'], 25, interpolation = 'midpoint')
Q3 = np.percentile(data['math score'], 75, interpolation = 'midpoint')
IQR = Q3 - Q1
IQR
# Out:
# C:\Users\vasek\AppData\Local\Temp\ipykernel_9064\3189913354.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(data['math score'], 25, interpolation = 'midpoint')
# C:\Users\vasek\AppData\Local\Temp\ipykernel_9064\3189913354.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(data['math score'], 75, interpolation = 'midpoint')
# 20.0

# %%
upper = data['math score'] >= (Q3+1.5*IQR)
 
print("Upper bound:",upper)
print(np.where(upper))
 
# Below Lower bound
lower = data['math score'] <= (Q1-1.5*IQR)
print("Lower bound:", lower)
print(np.where(lower))
# Out:
# Upper bound: 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: math score, Length: 1000, dtype: bool
# (array([], dtype=int64),)
# Lower bound: 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: math score, Length: 1000, dtype: bool
# (array([ 17,  59,  91, 145, 338, 363, 466, 787, 842, 980], dtype=int64),)

# %%
data.skew(axis = 0, skipna = True)

# %%
Q1 = np.percentile(data['math score'], 25,
                   interpolation = 'midpoint')
 
Q3 = np.percentile(data['math score'], 75,
                   interpolation = 'midpoint')
IQR = Q3 - Q1
upper = np.where(data['math score'] >= (Q3+1.5*IQR))
 
# Below Lower bound
lower = np.where(data['math score'] <= (Q1-1.5*IQR))
data.drop(upper[0], inplace = True)
data.drop(lower[0], inplace = True)
# Out:
# C:\Users\vasek\AppData\Local\Temp\ipykernel_9064\3656440728.py:1: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q1 = np.percentile(data['math score'], 25,
# C:\Users\vasek\AppData\Local\Temp\ipykernel_9064\3656440728.py:4: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(data['math score'], 75,

# %%
#Outliner detection  
arr = np.where(z>3)[0]  
# arr has only the indices where it has z>3 in a list form
print(arr)  
print("total outliners in it ",len(arr))
res=data.iloc[arr]
res
# Out:
# [ 59 327 596 980]
# total outliners in it  4
#     gender race/ethnicity parental level of education         lunch  \
# 61    male        group A            some high school  free/reduced
# 331   male        group C          associate's degree      standard
# 603   male        group D                 high school  free/reduced
# 990   male        group E                 high school  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 61                     none          39             39             34
# 331                    none          47             37             35
# 603                    none          60             57             51
# 990               completed          86             81             75

# %%
data.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
null_columns = data.columns[data.isnull().any()].tolist()
print("Null Columns ",null_columns)
data.dtypes
# Out:
# Null Columns  []
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
for column in null_columns:
    data[column] = pd.to_numeric(data[column], errors='coerce').astype('float')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
data.ffill()
data.bfill()
data.isna().sum()
# Out:
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64

# %%
z = np.abs(stats.zscore(data['math score']))
z
# Out:
# 0      0.376204
# 1      0.168715
# 2      1.621134
# 3      1.352866
# 4      0.652855
#          ...
# 995    1.482808
# 996    0.315424
# 997    0.522913
# 998    0.099552
# 999    0.722017
# Name: math score, Length: 990, dtype: float64

# %%
data_no_outliers = data[(z <= 3)] #for a new column
data=data[z<=3] # changes in same column
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# IQR 
# Calculate the first quartile (Q1) and third quartile (Q3) for 'fare_amount'
Q1 = data['Math_Score'].quantile(0.25)
Q3 = np.percentile(data['Math_Score'], 75, interpolation='midpoint')

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Print the results
print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)

# %%
# Above Upper bound
upper = data['Math_Score'] >= (Q3+1.5*IQR)
 
print("Upper bound:",Q3+1.5*IQR)
print(np.where(upper))
 
# Below Lower bound
lower = data['Math_Score'] <= (Q1-1.5*IQR)
print("Lower bound:", Q1-1.5*IQR)
print(np.where(lower))
# These are the outliers combining Upper Bounded Array and Lowe Bounded Array

# %%
print("New skew",data['math score'].skew())
# Out:
# New skew -0.04619025513163576

# %%
Q1 = data['writing score'].quantile(0.25)
Q3 = np.percentile(data['writing score'], 75, interpolation='midpoint')

# Calculate the Interquartile Range (IQR)
IQR = Q3 - Q1

# Print the results
print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print('Old skew',data['writing score'].skew())
data.plot(kind='hist', y='writing score')
print('New skew',data['writing score'].skew())
data.plot(kind='hist', y='writing score')
# Out:
# Q1: 58.0
# Q3: 79.0
# IQR: 21.0
# Old skew -0.19384829138181775
# New skew -0.19384829138181775
# C:\Users\vasek\AppData\Local\Temp\ipykernel_9064\1746296516.py:2: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they used. (Deprecated NumPy 1.22)
#   Q3 = np.percentile(data['writing score'], 75, interpolation='midpoint')
# <Axes: ylabel='Frequency'>

# %%
data.hist()

# %%
data.skew()

# %%
data['Writing_Score copy'] = np.sqrt(data['writing score'])
data.plot(kind='hist',y='Writing_Score copy')
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
sns.boxplot(x="math score",data=data)
# Out:
# <Axes: xlabel='math score'>

# %%
data['math score'] = data['math score'].fillna(data['math score'].mean())
data['math score'] = data['math score'].fillna(data['math score'].median())
data['math score'] = data['math score'].fillna(data['math score'].std())
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
import math
data2 = data.copy()
for i in data2.index:
    data2.at[i,'math score'] = math.log(data2['math score'][i])

# %%
data2.skew(axis = 0, skipna = True)
# Out:
# C:\Users\vasek\AppData\Local\Temp\ipykernel_9064\4073219304.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data2.skew(axis = 0, skipna = True)
# math score           -0.671030
# reading score        -0.173512
# writing score        -0.193848
# Writing_Score copy   -0.549805
# dtype: float64

# %%
data.skew(axis = 0, skipna = True)
# Out:
# C:\Users\vasek\AppData\Local\Temp\ipykernel_9064\2341530724.py:1: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.skew(axis = 0, skipna = True)
# math score           -0.046190
# reading score        -0.173512
# writing score        -0.193848
# Writing_Score copy   -0.549805
# dtype: float64

# %%
from scipy import stats
boxcox = stats.boxcox(data['math score'])[0]
pd.Series(boxcox).skew()
# Out:
# -0.030151450287674637
